# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Load the predicted dataset
csv_path = r"C:\Users\sagni\Downloads\Insider Threat Detection\threat_users.csv"
df = pd.read_csv(csv_path)

# Display prediction counts
print("🔢 Predicted Threat Label Counts:\n")
print(df['predicted_label'].value_counts())

# Visualize prediction distribution
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='predicted_label', palette='Set2')
plt.title('Distribution of Predicted Insider Threats')
plt.xlabel('Threat Label')
plt.ylabel('User Count')
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()

# Filter high-risk users (Malicious + Compromised)
high_risk = df[df['predicted_label'].isin(['Malicious Insider', 'Compromised Account'])]

# Preview top high-risk users
print("\n🚨 Sample High-Risk Users:")
print(high_risk.head())

# Save high-risk users to a new file
output_path = r"C:\Users\sagni\Downloads\Insider Threat Detection\high_risk_users.csv"
high_risk.to_csv(output_path, index=False)
print(f"\n✅ High-risk users saved to: {output_path}")
# Out:
# 🔢 Predicted Threat Label Counts:
#
# predicted_label
# Careless Insider       43
# Malicious Insider       4
# Compromised Account     3
# Name: count, dtype: int64
# C:\Users\sagni\AppData\Local\Temp\ipykernel_20968\522956860.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='predicted_label', palette='Set2')
# 🚨 Sample High-Risk Users:
#     user_id      predicted_label
# 1   user_10    Malicious Insider
# 15  user_23  Compromised Account
# 23  user_30    Malicious Insider
# 24  user_31  Compromised Account
# 26  user_33  Compromised Account
#
# ✅ High-risk users saved to: C:\Users\sagni\Downloads\Insider Threat Detection\high_risk_users.csv
